# %%
import pandas as pd

# %%
df = pd.read_csv('sb_short_30-05-1.csv', low_memory = False)
df.head()
# Out:
#    match_id  duration                                    id  index  \
# 0   3895302  0.052872  c577e730-b9f5-44f2-9257-9e7730c23d7b    436
# 1   3895302  0.217872  bbc2c68d-c096-483d-abf4-32c0175a0f55    480
# 2   3895302  0.445768  12b5206b-9ed0-4b1e-9ec3-f2028187e09f    597
# 3   3895302  0.085298  b2c3d59d-3bef-4f8a-ad86-26b69940c64e    684
# 4   3895302  0.402989  bb53b537-1685-4019-9e8f-98f3805828eb    848
#
#         location  minute off_camera  out  period    play_pattern  ...  \
# 0  [100.4, 35.1]       6        NaN  NaN       1  From Free Kick  ...
# 1  [114.6, 33.5]       7        NaN  NaN       1    Regular Play  ...
# 2  [106.2, 55.8]      11        NaN  NaN       1  From Free Kick  ...
# 3  [113.9, 47.4]      13        NaN  NaN       1     From Corner  ...
# 4   [89.2, 42.5]      16        NaN  NaN       1    Regular Play  ...
#
#   shot_saved_off_target  shot_saved_to_post shot_redirect  prev_shot_redirect  \
# 0                   NaN                 NaN           NaN                 NaN
# 1                   NaN                 NaN           NaN                 NaN
# 2                   NaN                 NaN           NaN                 NaN
# 3                   NaN                 NaN           NaN                 NaN
# 4                   NaN                 NaN           NaN                 NaN
#
#   shot_follows_dribble  prev_pass_backheel  \
# 0                  NaN                 NaN
# 1                  NaN                 NaN
# 2                  NaN                 NaN
# 3                  NaN                 NaN
# 4                  NaN                 NaN
#
#   prev_goalkeeper_penalty_saved_to_post  shot_kick_off      x     y
# 0                                   NaN            NaN  100.4  35.1
# 1                                   NaN            NaN  114.6  33.5
# 2                                   NaN            NaN  106.2  55.8
# 3                                   NaN            NaN  113.9  47.4
# 4                                   NaN            NaN   89.2  42.5
#
# [5 rows x 134 columns]

# %%
df.shape
# Out:
# (84981, 134)

# %%
import ast

def convert_to_list(s):
    """
    Convert a string representation of a list to an actual list.
    If the conversion fails, return an empty list and print an error message.
    """
    try:
        return ast.literal_eval(s)
    except (ValueError, SyntaxError):
        print(f"Could not convert {s} to list.")
        return []
    
df.dropna(subset= ['prev_location', 'shot_freeze_frame'], inplace= True)
    
df['prev_location'] = df['prev_location'].apply(convert_to_list)
df['shot_freeze_frame'] = df['shot_freeze_frame'].apply(convert_to_list)

# %%
def calculate_distances2(row):
    shot_freeze_frame = row['shot_freeze_frame']
    shot_x = row['x']
    shot_y = row['y']
    
    # Initialize columns for positions and distances
    columns = {
        'goalkeeper_x': None,
        'goalkeeper_y': None,
        'goalkeeper_dx': None,
        'goalkeeper_dy': None
    }
    teammate_data = []
    opposition_data = []

    if not isinstance(shot_freeze_frame, list):
        print(f"Unexpected data format for shot_freeze_frame: {shot_freeze_frame}")
        return pd.Series(columns)

    # Sort entries by Euclidean distance
    shot_freeze_frame_sorted = sorted(shot_freeze_frame, key=lambda entry: ((entry['location'][0] - shot_x)**2 + (entry['location'][1] - shot_y)**2))

    for entry in shot_freeze_frame_sorted:
        if not isinstance(entry, dict):
            print(f"Unexpected entry format: {entry}")
            continue

        x, y = entry['location']
        dx = x - shot_x
        dy = y - shot_y

        if entry['position']['name'] == 'Goalkeeper' and entry['teammate'] == False:
            columns['goalkeeper_x'] = x
            columns['goalkeeper_y'] = y
            columns['goalkeeper_dx'] = dx
            columns['goalkeeper_dy'] = dy
        else:
            player_data = {
                'x': x,
                'y': y,
                'dx': dx,
                'dy': dy
            }
            if entry['teammate']:
                teammate_data.append(player_data)
            else:
                opposition_data.append(player_data)
    
    # Flatten the lists and create columns dynamically
    for idx, player_data in enumerate(teammate_data, start=1):
        columns[f'teammate_{idx}_x'] = player_data['x']
        columns[f'teammate_{idx}_y'] = player_data['y']
        columns[f'teammate_{idx}_dx'] = player_data['dx']
        columns[f'teammate_{idx}_dy'] = player_data['dy']
        
    for idx, player_data in enumerate(opposition_data, start=1):
        columns[f'opposition_{idx}_x'] = player_data['x']
        columns[f'opposition_{idx}_y'] = player_data['y']
        columns[f'opposition_{idx}_dx'] = player_data['dx']
        columns[f'opposition_{idx}_dy'] = player_data['dy']

    return pd.Series(columns)

# Apply the function to each row
distance_columns = df.apply(calculate_distances2, axis=1)

# Combine the new columns with the original DataFrame
df = pd.concat([df, distance_columns], axis=1)

# %%
dfd = df.copy()
dfd = dfd[['x', 'y', 'goalkeeper_dx', 'goalkeeper_dy', 'opposition_10_dx', 'opposition_10_dy', 'opposition_1_dx', 'opposition_1_dy', 'opposition_2_dx', 'opposition_2_dy', 'opposition_3_dx', 'opposition_3_dy', 'opposition_4_dx', 'opposition_4_dy', 'opposition_5_dx', 'opposition_5_dy', 'opposition_6_dx', 'opposition_6_dy', 'opposition_7_dx', 'opposition_7_dy', 'opposition_8_dx', 'opposition_8_dy', 'opposition_9_dx', 'opposition_9_dy', 'teammate_10_dx', 'teammate_10_dy', 'teammate_1_dx', 'teammate_1_dy', 'teammate_2_dx', 'teammate_2_dy', 'teammate_3_dx', 'teammate_3_dy', 'teammate_4_dx', 'teammate_4_dy', 'teammate_5_dx', 'teammate_5_dy', 'teammate_6_dx', 'teammate_6_dy', 'teammate_7_dx', 'teammate_7_dy', 'teammate_8_dx', 'teammate_8_dy', 'teammate_9_dx', 'teammate_9_dy']]
dfd.head()
# Out:
#        x     y  goalkeeper_dx  goalkeeper_dy  opposition_10_dx  \
# 0  100.4  35.1           18.0            3.4               NaN
# 1  114.6  33.5            3.7            2.9               NaN
# 2  106.2  55.8           12.0          -12.9               NaN
# 3  113.9  47.4            5.0           -5.5              -4.4
# 4   89.2  42.5           27.7           -2.4               NaN
#
#    opposition_10_dy  opposition_1_dx  opposition_1_dy  opposition_2_dx  \
# 0               NaN              1.5              0.0              5.0
# 1               NaN             -0.3              1.1             -1.6
# 2               NaN              2.7              3.9              2.9
# 3             -15.2              0.2             -1.0             -0.7
# 4               NaN              2.7              1.3              3.1
#
#    opposition_2_dy  ...  teammate_5_dx  teammate_5_dy  teammate_6_dx  \
# 0             -3.6  ...          -10.6           -5.2           12.8
# 1              3.6  ...          -15.5           26.6            NaN
# 2             -5.0  ...          -12.6          -28.3            NaN
# 3             -0.8  ...            1.8          -12.3          -18.0
# 4             -1.9  ...           -2.5           16.6           13.6
#
#    teammate_6_dy  teammate_7_dx  teammate_7_dy  teammate_8_dx  teammate_8_dy  \
# 0            3.4           -5.9          -15.2            NaN            NaN
# 1            NaN            NaN            NaN            NaN            NaN
# 2            NaN            NaN            NaN            NaN            NaN
# 3            2.0            2.1          -42.1            NaN            NaN
# 4           16.1            8.0          -28.0            NaN            NaN
#
#    teammate_9_dx  teammate_9_dy
# 0            NaN            NaN
# 1            NaN            NaN
# 2            NaN            NaN
# 3            NaN            NaN
# 4            NaN            NaN
#
# [5 rows x 44 columns]

# %%
print(dfd.isna().sum())
# Out:
# x                       0
# y                       0
# goalkeeper_dx          98
# goalkeeper_dy          98
# opposition_10_dx    70384
# opposition_10_dy    70384
# opposition_1_dx       147
# opposition_1_dy       147
# opposition_2_dx       299
# opposition_2_dy       299
# opposition_3_dx      1046
# opposition_3_dy      1046
# opposition_4_dx      3112
# opposition_4_dy      3112
# opposition_5_dx      6876
# opposition_5_dy      6876
# opposition_6_dx     13105
# opposition_6_dy     13105
# opposition_7_dx     23446
# opposition_7_dy     23446
# opposition_8_dx     38438
# opposition_8_dy     38438
# opposition_9_dx     55257
# opposition_9_dy     55257
# teammate_10_dx      83636
# teammate_10_dy      83636
# teammate_1_dx        1295
# teammate_1_dy        1295
# teammate_2_dx        5078
# teammate_2_dy        5078
# teammate_3_dx       13460
# teammate_3_dy       13460
# teammate_4_dx       27235
# teammate_4_dy       27235
# teammate_5_dx       43459
# teammate_5_dy       43459
# teammate_6_dx       59184
# teammate_6_dy       59184
# teammate_7_dx       71589
# teammate_7_dy       71589
# teammate_8_dx       79744
# teammate_8_dy       79744
# teammate_9_dx       82930
# teammate_9_dy       82930
# dtype: int64

# %%
df.head()
# Out:
#    match_id  duration                                    id  index  \
# 0   3895302  0.052872  c577e730-b9f5-44f2-9257-9e7730c23d7b    436
# 1   3895302  0.217872  bbc2c68d-c096-483d-abf4-32c0175a0f55    480
# 2   3895302  0.445768  12b5206b-9ed0-4b1e-9ec3-f2028187e09f    597
# 3   3895302  0.085298  b2c3d59d-3bef-4f8a-ad86-26b69940c64e    684
# 4   3895302  0.402989  bb53b537-1685-4019-9e8f-98f3805828eb    848
#
#         location  minute off_camera  out  period    play_pattern  ...  \
# 0  [100.4, 35.1]       6        NaN  NaN       1  From Free Kick  ...
# 1  [114.6, 33.5]       7        NaN  NaN       1    Regular Play  ...
# 2  [106.2, 55.8]      11        NaN  NaN       1  From Free Kick  ...
# 3  [113.9, 47.4]      13        NaN  NaN       1     From Corner  ...
# 4   [89.2, 42.5]      16        NaN  NaN       1    Regular Play  ...
#
#   teammate_7_x  teammate_7_y teammate_8_dx  teammate_8_dy teammate_8_x  \
# 0         94.5          19.9           NaN            NaN          NaN
# 1          NaN           NaN           NaN            NaN          NaN
# 2          NaN           NaN           NaN            NaN          NaN
# 3        116.0           5.3           NaN            NaN          NaN
# 4         97.2          14.5           NaN            NaN          NaN
#
#    teammate_8_y teammate_9_dx  teammate_9_dy teammate_9_x teammate_9_y
# 0           NaN           NaN            NaN          NaN          NaN
# 1           NaN           NaN            NaN          NaN          NaN
# 2           NaN           NaN            NaN          NaN          NaN
# 3           NaN           NaN            NaN          NaN          NaN
# 4           NaN           NaN            NaN          NaN          NaN
#
# [5 rows x 218 columns]

# %%
df.dropna(subset = ['goalkeeper_dx', 'goalkeeper_dy','teammate_1_dx', 'teammate_1_dy', 'teammate_2_dx', 'teammate_2_dy',
                   'opposition_1_dx', 'opposition_1_dy', 'opposition_2_dx', 'opposition_2_dy', 'opposition_3_dx', 'opposition_3_dy', 'opposition_4_dx', 'opposition_4_dy'], inplace = True)

# %%
for column in df.columns:
    print(f"{column}: {df[column].isna().sum()}")
# Out:
# match_id: 0
# duration: 0
# id: 0
# index: 0
# location: 0
# minute: 0
# off_camera: 77516
# out: 76253
# period: 0
# play_pattern: 0
# player: 0
# player_id: 0
# position: 0
# possession: 0
# possession_team: 0
# possession_team_id: 0
# related_events: 0
# second: 0
# shot_aerial_won: 70729
# shot_body_part: 0
# shot_end_location: 0
# shot_first_time: 53769
# shot_freeze_frame: 0
# shot_key_pass_id: 22448
# shot_one_on_one: 74584
# shot_outcome: 0
# shot_statsbomb_xg: 0
# shot_technique: 0
# shot_type: 0
# team: 0
# team_id: 0
# timestamp: 0
# type: 0
# under_pressure: 59106
# prev_50_50: 77615
# prev_bad_behaviour_card: 77617
# prev_ball_recovery_recovery_failure: 77613
# prev_carry_end_location: 41715
# prev_clearance_body_part: 77616
# prev_clearance_right_foot: 77616
# prev_counterpress: 77581
# prev_dribble_nutmeg: 77616
# prev_dribble_outcome: 77565
# prev_duel_outcome: 77599
# prev_duel_type: 77595
# prev_duration: 231
# prev_foul_won_advantage: 77555
# prev_foul_won_defensive: 76936
# prev_foul_won_penalty: 77617
# prev_goalkeeper_body_part: 77617
# prev_goalkeeper_outcome: 77617
# prev_goalkeeper_position: 77617
# prev_goalkeeper_technique: 77617
# prev_goalkeeper_type: 77617
# prev_id: 0
# prev_index: 0
# prev_interception_outcome: 77601
# prev_location: 0
# prev_match_id: 0
# prev_minute: 0
# prev_off_camera: 77013
# prev_out: 77616
# prev_pass_aerial_won: 76942
# prev_pass_angle: 49302
# prev_pass_assisted_shot_id: 49674
# prev_pass_body_part: 50159
# prev_pass_cross: 67383
# prev_pass_cut_back: 76412
# prev_pass_deflected: 77489
# prev_pass_end_location: 49302
# prev_pass_goal_assist: 74258
# prev_pass_height: 49302
# prev_pass_inswinging: 75775
# prev_pass_length: 49302
# prev_pass_outcome: 77499
# prev_pass_outswinging: 75006
# prev_pass_recipient: 49343
# prev_pass_recipient_id: 49343
# prev_pass_shot_assist: 53033
# prev_pass_switch: 74509
# prev_pass_technique: 71628
# prev_pass_through_ball: 76536
# prev_pass_type: 68306
# prev_period: 0
# prev_play_pattern: 0
# prev_player: 0
# prev_player_id: 0
# prev_position: 0
# prev_possession: 0
# prev_possession_team: 0
# prev_possession_team_id: 0
# prev_related_events: 7442
# prev_second: 0
# prev_shot_aerial_won: 77598
# prev_shot_body_part: 77503
# prev_shot_end_location: 77503
# prev_shot_first_time: 77577
# prev_shot_freeze_frame: 77503
# prev_shot_key_pass_id: 77543
# prev_shot_one_on_one: 77615
# prev_shot_outcome: 77503
# prev_shot_statsbomb_xg: 77503
# prev_shot_technique: 77503
# prev_shot_type: 77503
# prev_substitution_outcome: 77617
# prev_substitution_outcome_id: 77617
# prev_substitution_replacement: 77617
# prev_substitution_replacement_id: 77617
# prev_tactics: 77617
# prev_team: 0
# prev_team_id: 0
# prev_timestamp: 0
# prev_type: 0
# prev_under_pressure: 52198
# prev_ball_recovery_offensive: 77579
# prev_block_offensive: 77524
# prev_dribble_overrun: 77614
# prev_miscontrol_aerial_won: 77616
# shot_deflected: 76593
# prev_shot_deflected: 77617
# prev_pass_no_touch: 77530
# shot_open_goal: 76879
# prev_pass_straight: 77162
# prev_dribble_no_touch: 77612
# shot_saved_off_target: 77290
# shot_saved_to_post: 77376
# shot_redirect: 77425
# prev_shot_redirect: 77615
# shot_follows_dribble: 77565
# prev_pass_backheel: 77608
# prev_goalkeeper_penalty_saved_to_post: 77617
# shot_kick_off: 77617
# x: 0
# y: 0
# goalkeeper_dx: 0
# goalkeeper_dy: 0
# goalkeeper_x: 0
# goalkeeper_y: 0
# opposition_10_dx: 64362
# opposition_10_dy: 64362
# opposition_10_x: 64362
# opposition_10_y: 64362
# opposition_1_dx: 0
# opposition_1_dy: 0
# opposition_1_x: 0
# opposition_1_y: 0
# opposition_2_dx: 0
# opposition_2_dy: 0
# opposition_2_x: 0
# opposition_2_y: 0
# opposition_3_dx: 0
# opposition_3_dy: 0
# opposition_3_x: 0
# opposition_3_y: 0
# opposition_4_dx: 0
# opposition_4_dy: 0
# opposition_4_x: 0
# opposition_4_y: 0
# opposition_5_dx: 2440
# opposition_5_dy: 2440
# opposition_5_x: 2440
# opposition_5_y: 2440
# opposition_6_dx: 7836
# opposition_6_dy: 7836
# opposition_6_x: 7836
# opposition_6_y: 7836
# opposition_7_dx: 17698
# opposition_7_dy: 17698
# opposition_7_x: 17698
# opposition_7_y: 17698
# opposition_8_dx: 32490
# opposition_8_dy: 32490
# opposition_8_x: 32490
# opposition_8_y: 32490
# opposition_9_dx: 49255
# opposition_9_dy: 49255
# opposition_9_x: 49255
# opposition_9_y: 49255
# teammate_10_dx: 77610
# teammate_10_dy: 77610
# teammate_10_x: 77610
# teammate_10_y: 77610
# teammate_1_dx: 0
# teammate_1_dy: 0
# teammate_1_x: 0
# teammate_1_y: 0
# teammate_2_dx: 0
# teammate_2_dy: 0
# teammate_2_x: 0
# teammate_2_y: 0
# teammate_3_dx: 7686
# teammate_3_dy: 7686
# teammate_3_x: 7686
# teammate_3_y: 7686
# teammate_4_dx: 21289
# teammate_4_dy: 21289
# teammate_4_x: 21289
# teammate_4_y: 21289
# teammate_5_dx: 37474
# teammate_5_dy: 37474
# teammate_5_x: 37474
# teammate_5_y: 37474
# teammate_6_dx: 53181
# teammate_6_dy: 53181
# teammate_6_x: 53181
# teammate_6_y: 53181
# teammate_7_dx: 65578
# teammate_7_dy: 65578
# teammate_7_x: 65578
# teammate_7_y: 65578
# teammate_8_dx: 73725
# teammate_8_dy: 73725
# teammate_8_x: 73725
# teammate_8_y: 73725
# teammate_9_dx: 76906
# teammate_9_dy: 76906
# teammate_9_x: 76906
# teammate_9_y: 76906

# %%
df_slim = df.copy()
df_slim = df[['x', 'y', 'goalkeeper_dx', 'goalkeeper_dy', 'opposition_1_dx', 'opposition_1_dy', 'opposition_2_dx', 'opposition_2_dy', 'opposition_3_dx', 'opposition_3_dy', 'opposition_4_dx', 
              'opposition_4_dy', 'teammate_1_dx', 'teammate_1_dy', 'teammate_2_dx', 'teammate_2_dy', 
              'goalkeeper_x', 'goalkeeper_y', 'opposition_1_x', 'opposition_1_y', 'opposition_2_x', 'opposition_2_y', 'opposition_3_x', 'opposition_3_y', 'opposition_4_x', 
              'opposition_4_y', 'teammate_1_x', 'teammate_1_y', 'teammate_2_x', 'teammate_2_y',
              'play_pattern', 'shot_aerial_won', 'shot_body_part', 'shot_first_time', 'shot_one_on_one', 
              'shot_outcome', 'shot_technique', 'shot_statsbomb_xg', 'shot_type', 'under_pressure', 'prev_type', 'prev_location',
              ]]

df_slim.head()
# Out:
#        x     y  goalkeeper_dx  goalkeeper_dy  opposition_1_dx  \
# 0  100.4  35.1           18.0            3.4              1.5
# 1  114.6  33.5            3.7            2.9             -0.3
# 2  106.2  55.8           12.0          -12.9              2.7
# 3  113.9  47.4            5.0           -5.5              0.2
# 4   89.2  42.5           27.7           -2.4              2.7
#
#    opposition_1_dy  opposition_2_dx  opposition_2_dy  opposition_3_dx  \
# 0              0.0              5.0             -3.6              6.8
# 1              1.1             -1.6              3.6              0.0
# 2              3.9              2.9             -5.0              2.7
# 3             -1.0             -0.7             -0.8             -0.9
# 4              1.3              3.1             -1.9              1.9
#
#    opposition_3_dy  ...  shot_body_part  shot_first_time  shot_one_on_one  \
# 0              3.0  ...      Right Foot             True              NaN
# 1              5.6  ...       Left Foot             True              NaN
# 2             -9.6  ...       Left Foot             True              NaN
# 3             -2.3  ...            Head              NaN              NaN
# 4              9.0  ...       Left Foot              NaN              NaN
#
#    shot_outcome  shot_technique  shot_statsbomb_xg  shot_type  under_pressure  \
# 0       Blocked          Normal           0.056644  Open Play             NaN
# 1         Saved          Normal           0.143381  Open Play            True
# 2       Blocked          Normal           0.038188  Open Play             NaN
# 3       Blocked          Normal           0.052781  Open Play             NaN
# 4       Blocked          Normal           0.021272  Open Play            True
#
#        prev_type  prev_location
# 0  Ball Recovery  [101.7, 35.6]
# 1           Pass  [111.0, 69.2]
# 2  Ball Recovery  [105.8, 56.5]
# 3           Pass   [120.0, 0.1]
# 4          Carry   [87.6, 46.0]
#
# [5 rows x 42 columns]

# %%
df_slim.shape
# Out:
# (77617, 42)

# %%
for column in df_slim.columns:
    print(f"{column}: {df_slim[column].isna().sum()}")
# Out:
# x: 0
# y: 0
# goalkeeper_dx: 0
# goalkeeper_dy: 0
# opposition_1_dx: 0
# opposition_1_dy: 0
# opposition_2_dx: 0
# opposition_2_dy: 0
# opposition_3_dx: 0
# opposition_3_dy: 0
# opposition_4_dx: 0
# opposition_4_dy: 0
# teammate_1_dx: 0
# teammate_1_dy: 0
# teammate_2_dx: 0
# teammate_2_dy: 0
# goalkeeper_x: 0
# goalkeeper_y: 0
# opposition_1_x: 0
# opposition_1_y: 0
# opposition_2_x: 0
# opposition_2_y: 0
# opposition_3_x: 0
# opposition_3_y: 0
# opposition_4_x: 0
# opposition_4_y: 0
# teammate_1_x: 0
# teammate_1_y: 0
# teammate_2_x: 0
# teammate_2_y: 0
# play_pattern: 0
# shot_aerial_won: 70729
# shot_body_part: 0
# shot_first_time: 53769
# shot_one_on_one: 74584
# shot_outcome: 0
# shot_technique: 0
# shot_statsbomb_xg: 0
# shot_type: 0
# under_pressure: 59106
# prev_type: 0
# prev_location: 0

# %%
df_slim = df_slim.reset_index(drop=True)

# %%
df_slim['shot_one_on_one'] = df_slim['shot_one_on_one'].fillna(False)
df_slim['shot_aerial_won'] = df_slim['shot_aerial_won'].fillna(False)
df_slim['shot_first_time'] = df_slim['shot_first_time'].fillna(False)
df_slim['under_pressure'] = df_slim['under_pressure'].fillna(False)

# %%
for column in df_slim.columns:
    print(f"{column}: {df_slim[column].isna().sum()}")
# Out:
# x: 0
# y: 0
# goalkeeper_dx: 0
# goalkeeper_dy: 0
# opposition_1_dx: 0
# opposition_1_dy: 0
# opposition_2_dx: 0
# opposition_2_dy: 0
# opposition_3_dx: 0
# opposition_3_dy: 0
# opposition_4_dx: 0
# opposition_4_dy: 0
# teammate_1_dx: 0
# teammate_1_dy: 0
# teammate_2_dx: 0
# teammate_2_dy: 0
# goalkeeper_x: 0
# goalkeeper_y: 0
# opposition_1_x: 0
# opposition_1_y: 0
# opposition_2_x: 0
# opposition_2_y: 0
# opposition_3_x: 0
# opposition_3_y: 0
# opposition_4_x: 0
# opposition_4_y: 0
# teammate_1_x: 0
# teammate_1_y: 0
# teammate_2_x: 0
# teammate_2_y: 0
# play_pattern: 0
# shot_aerial_won: 0
# shot_body_part: 0
# shot_first_time: 0
# shot_one_on_one: 0
# shot_outcome: 0
# shot_technique: 0
# shot_statsbomb_xg: 0
# shot_type: 0
# under_pressure: 0
# prev_type: 0
# prev_location: 0

# %%
df_slim['goal'] = df_slim['shot_outcome']=='Goal'
df_slim.head(30)
# Out:
#         x     y  goalkeeper_dx  goalkeeper_dy  opposition_1_dx  \
# 0   100.4  35.1           18.0            3.4              1.5
# 1   114.6  33.5            3.7            2.9             -0.3
# 2   106.2  55.8           12.0          -12.9              2.7
# 3   113.9  47.4            5.0           -5.5              0.2
# 4    89.2  42.5           27.7           -2.4              2.7
# 5   110.2  32.6            9.0            5.9              0.7
# 6   105.4  45.1           12.0           -3.4              0.7
# 7   101.5  47.5           16.3           -6.4              1.9
# 8   116.3  46.0            2.3           -3.3             -1.1
# 9   116.3  43.3            2.5           -0.7              0.6
# 10  109.4  44.9            9.5           -3.4             -1.0
# 11  113.1  27.5            5.1            7.5              0.1
# 12  110.1  41.6            8.9           -1.2              0.5
# 13  115.9  40.1            1.8           -0.1             -1.6
# 14   97.5  40.8           20.3           -0.4              1.3
# 15   93.8  34.8           24.8            5.1              4.5
# 16   93.0  39.1           25.6            0.8              5.2
# 17  106.3  29.6           12.2            7.7             -1.1
# 18   93.5  40.1           23.2           -0.2             -0.9
# 19  112.5  29.6            3.0            5.1             -0.4
# 20  108.0  51.1            8.7           -6.7              1.3
# 21  108.1  27.2            9.9            9.6              2.3
# 22   98.2  42.1           17.8           -1.4              2.0
# 23  101.6  43.3           15.8           -2.3              1.7
# 24  106.4  48.8            8.3           -4.8             -0.2
# 25  107.0  53.4           10.6          -10.7             -2.0
# 26   96.5  39.9           21.3           -0.2             -0.5
# 27   88.2  45.5           29.4           -5.9              5.3
# 28   98.5  49.2           20.3           -9.6              9.4
# 29  111.2  37.8            6.9            2.3              0.6
#
#     opposition_1_dy  opposition_2_dx  opposition_2_dy  opposition_3_dx  \
# 0               0.0              5.0             -3.6              6.8
# 1               1.1             -1.6              3.6              0.0
# 2               3.9              2.9             -5.0              2.7
# 3              -1.0             -0.7             -0.8             -0.9
# 4               1.3              3.1             -1.9              1.9
# 5              -0.1              0.5              1.3              0.8
# 6              -0.4             -3.0              0.0             -0.6
# 7              -0.4              2.0             -9.0              7.9
# 8              -0.2             -0.7             -1.2              0.2
# 9               1.8             -2.5             -1.4              0.1
# 10             -1.6              3.4             -1.4              7.1
# 11              1.6             -0.1              8.7             -8.3
# 12             -1.3              3.7             -2.0              4.3
# 13              0.5             -7.3              0.6            -10.4
# 14              0.9             -0.9             -2.4             -1.4
# 15             -0.2              7.0              4.1             13.9
# 16             -3.0              6.7             -5.9             -0.9
# 17              2.5              2.0             -2.4              3.1
# 18              1.2             -0.3             -2.8              7.4
# 19              6.4            -10.0             -0.7              1.4
# 20             -6.3             -5.6             -4.4             -9.4
# 21              1.6              1.8              9.0             -2.2
# 22              2.3              8.2             -2.7              8.9
# 23             -1.5              1.7              5.5              7.0
# 24             -1.3              0.4             -4.1             -6.1
# 25              0.5             -3.4             -1.7              0.7
# 26              6.3              5.6              3.2              8.6
# 27             -1.2              5.1              3.1             -3.5
# 28             -2.1              9.3             -2.9              9.2
# 29             -0.5              0.6              4.8              0.2
#
#     opposition_3_dy  ...  shot_first_time  shot_one_on_one  shot_outcome  \
# 0               3.0  ...             True            False       Blocked
# 1               5.6  ...             True            False         Saved
# 2              -9.6  ...             True            False       Blocked
# 3              -2.3  ...            False            False       Blocked
# 4               9.0  ...            False            False       Blocked
# 5              -1.2  ...            False            False       Wayward
# 6              -6.0  ...            False            False       Blocked
# 7              -5.6  ...             True            False       Blocked
# 8              -1.8  ...            False            False         Saved
# 9              -3.5  ...             True            False         Saved
# 10             -1.1  ...            False            False       Blocked
# 11              3.5  ...            False            False          Post
# 12              0.0  ...            False            False       Blocked
# 13             -4.2  ...            False             True         Saved
# 14              5.5  ...            False            False         Saved
# 15              2.4  ...            False            False         Off T
# 16             11.0  ...             True            False          Goal
# 17              2.4  ...            False            False       Blocked
# 18              3.5  ...            False            False          Goal
# 19             12.7  ...             True            False         Saved
# 20             -1.2  ...            False            False         Saved
# 21             10.7  ...            False            False         Saved
# 22              2.4  ...             True            False         Off T
# 23             -0.7  ...             True            False         Off T
# 24             -8.9  ...            False            False          Goal
# 25             -6.0  ...            False            False         Off T
# 26             -0.1  ...             True            False       Blocked
# 27              5.2  ...            False            False       Blocked
# 28             -3.7  ...            False            False         Saved
# 29             -5.9  ...            False            False         Saved
#
#     shot_technique  shot_statsbomb_xg  shot_type  under_pressure  \
# 0           Normal           0.056644  Open Play           False
# 1           Normal           0.143381  Open Play            True
# 2           Normal           0.038188  Open Play           False
# 3           Normal           0.052781  Open Play           False
# 4           Normal           0.021272  Open Play            True
# 5           Normal           0.029664  Open Play            True
# 6           Normal           0.082293  Open Play            True
# 7           Normal           0.050110  Open Play           False
# 8           Normal           0.109917  Open Play            True
# 9           Volley           0.323069  Open Play           False
# 10          Normal           0.095424  Open Play           False
# 11          Normal           0.074157  Open Play            True
# 12          Normal           0.067553  Open Play           False
# 13          Normal           0.375736  Open Play           False
# 14          Normal           0.048408  Open Play            True
# 15          Normal           0.024202  Open Play            True
# 16          Normal           0.031473  Open Play           False
# 17          Normal           0.076220  Open Play           False
# 18          Normal           0.042012  Open Play           False
# 19     Half Volley           0.109270  Open Play           False
# 20          Normal           0.173471  Open Play           False
# 21     Half Volley           0.047987  Open Play           False
# 22     Half Volley           0.034476  Open Play           False
# 23          Normal           0.068442  Open Play           False
# 24          Normal           0.289998  Open Play           False
# 25     Half Volley           0.084877  Open Play           False
# 26          Normal           0.042399  Open Play           False
# 27          Normal           0.017574  Open Play           False
# 28          Normal           0.075614  Free Kick           False
# 29          Normal           0.118389  Open Play            True
#
#         prev_type  prev_location   goal
# 0   Ball Recovery  [101.7, 35.6]  False
# 1            Pass  [111.0, 69.2]  False
# 2   Ball Recovery  [105.8, 56.5]  False
# 3            Pass   [120.0, 0.1]  False
# 4           Carry   [87.6, 46.0]  False
# 5            Pass  [120.0, 80.0]  False
# 6           Carry  [105.6, 48.9]  False
# 7            Pass  [120.0, 80.0]  False
# 8            Pass   [120.0, 0.1]  False
# 9   Ball Recovery  [116.5, 42.9]  False
# 10          Carry  [105.3, 45.2]  False
# 11          Carry  [108.2, 21.8]  False
# 12           Pass  [120.0, 80.0]  False
# 13           Pass   [97.0, 13.5]  False
# 14          Carry   [91.3, 47.7]  False
# 15          Carry   [93.7, 35.1]  False
# 16           Pass  [101.7, 28.5]   True
# 17          Carry  [106.1, 25.3]  False
# 18          Carry   [88.4, 38.3]   True
# 19           Pass  [101.0, 67.0]  False
# 20          Carry   [96.9, 53.9]  False
# 21          Carry  [105.2, 27.7]  False
# 22  Ball Recovery   [99.0, 41.4]  False
# 23           Pass  [104.1, 54.0]  False
# 24          Carry   [89.4, 55.4]   True
# 25          Carry   [93.8, 54.4]  False
# 26           Pass  [101.8, 46.8]  False
# 27          Carry   [88.7, 47.2]  False
# 28       Foul Won   [98.5, 50.3]  False
# 29           Pass  [106.7, 58.6]  False
#
# [30 rows x 43 columns]

# %%
df_slim[['prev_x','prev_y']] = df_slim['prev_location'].to_list()
df_slim['prev_x'] = df_slim['prev_x'].astype(float)
df_slim['prev_y'] = df_slim['prev_y'].astype(float)

# %%
df_slim.drop(['prev_location'], axis=1, inplace = True)

# %%
df_slim.head()
# Out:
#        x     y  goalkeeper_dx  goalkeeper_dy  opposition_1_dx  \
# 0  100.4  35.1           18.0            3.4              1.5
# 1  114.6  33.5            3.7            2.9             -0.3
# 2  106.2  55.8           12.0          -12.9              2.7
# 3  113.9  47.4            5.0           -5.5              0.2
# 4   89.2  42.5           27.7           -2.4              2.7
#
#    opposition_1_dy  opposition_2_dx  opposition_2_dy  opposition_3_dx  \
# 0              0.0              5.0             -3.6              6.8
# 1              1.1             -1.6              3.6              0.0
# 2              3.9              2.9             -5.0              2.7
# 3             -1.0             -0.7             -0.8             -0.9
# 4              1.3              3.1             -1.9              1.9
#
#    opposition_3_dy  ...  shot_one_on_one  shot_outcome  shot_technique  \
# 0              3.0  ...            False       Blocked          Normal
# 1              5.6  ...            False         Saved          Normal
# 2             -9.6  ...            False       Blocked          Normal
# 3             -2.3  ...            False       Blocked          Normal
# 4              9.0  ...            False       Blocked          Normal
#
#    shot_statsbomb_xg  shot_type  under_pressure      prev_type   goal  prev_x  \
# 0           0.056644  Open Play           False  Ball Recovery  False   101.7
# 1           0.143381  Open Play            True           Pass  False   111.0
# 2           0.038188  Open Play           False  Ball Recovery  False   105.8
# 3           0.052781  Open Play           False           Pass  False   120.0
# 4           0.021272  Open Play            True          Carry  False    87.6
#
#    prev_y
# 0    35.6
# 1    69.2
# 2    56.5
# 3     0.1
# 4    46.0
#
# [5 rows x 44 columns]

# %%
df_slim.to_csv('sb_30-05_slim_slim-1.csv', index=False)
